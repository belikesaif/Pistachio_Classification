# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense

# Load your dataset
df = pd.read_csv("/content/Pistachio_Dataset.csv")

# Split the data into features (X) and labels (y)
features = df.iloc[:, 2:-1].values  # Exclude the 'id' and 'Class' columns
labels = df['Class'].values

# %%
# One-hot encode the labels
labels = pd.get_dummies(labels)
print(labels)


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# Standardize the features (mean=0, variance=1)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
#       Kirmizi_Pistachio  Siit_Pistachio
# 0                     1               0
# 1                     1               0
# 2                     1               0
# 3                     1               0
# 4                     1               0
# ...                 ...             ...
# 2143                  0               1
# 2144                  0               1
# 2145                  0               1
# 2146                  0               1
# 2147                  0               1
#
# [2148 rows x 2 columns]

# %%
# Define the neural network model
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=X_train.shape[1]))  # Input layer with input_dim
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=2, activation='softmax'))  # Output layer for binary classification with two classes

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Model Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Epoch 1/200
# 47/47 [==============================] - 1s 8ms/step - loss: 0.4992 - accuracy: 0.7971 - val_loss: 0.3895 - val_accuracy: 0.8589
# Epoch 2/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3440 - accuracy: 0.8636 - val_loss: 0.3241 - val_accuracy: 0.8760
# Epoch 3/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.8643 - val_loss: 0.3128 - val_accuracy: 0.8682
# Epoch 4/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3093 - accuracy: 0.8736 - val_loss: 0.3101 - val_accuracy: 0.8713
# Epoch 5/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3059 - accuracy: 0.8749 - val_loss: 0.3091 - val_accuracy: 0.8651
# Epoch 6/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3039 - accuracy: 0.8736 - val_loss: 0.3070 - val_accuracy: 0.8713
# Epoch 7/200
# ...

# %%
score = model.evaluate(X_test, y_test)

print('Test Loss:', score[0])
print('Test Accuracy:', score[1])
# Out:
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8465
# Test Loss: 0.3412633240222931
# Test Accuracy: 0.8465116024017334
